# %% [markdown]
# # Problem Statement:

# %% [markdown]
# There are 16 different features that will be used as the inputs to the machine learning and the output will be a value that represents the number of wins.
# Input features: Runs, At Bats, Hits, Doubles, Triples, Homeruns, Walks, Strikeouts, Stolen Bases, Runs Allowed, Earned Runs, Earned Run Average (ERA), Shutouts, Saves, Complete Games and Errors
# Output: Number of predicted wins (W)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Read csv file as DataFrame(df):

# %%
df=pd.read_csv("Baseball_Project")
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
df.shape # checking number of columns and rows present in the dataset.
# Out:
# (30, 17)

# %%
df.head() # Top 5 data from the dataset.
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
df.tail() #last 5 data from the dataset.
# Out:
#      W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 25  92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26  84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27  79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28  74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29  68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV   E
# 25   21  47  75
# 26   18  41  78
# 27   12  44  86
# 28    6  41  92
# 29    4  36  95

# %% [markdown]
# From the above information we can say that the data contains 30 columns and 17 rows; from the head and tail we are now assured that the displayed data is correct. Now we can processed furthur.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %% [markdown]
# From info we can say that,16 dtypes is int64 and 1 is float64 datatype.
# And the data type is continuous. so regression models are the best fit model.

# %% [markdown]
# # Checking the null values:

# %%
#checking if any null value is present or not.
df.isnull()
# Out:
#         W      R     AB      H     2B     3B     HR     BB     SO     SB  \
# 0   False  False  False  False  False  False  False  False  False  False
# 1   False  False  False  False  False  False  False  False  False  False
# 2   False  False  False  False  False  False  False  False  False  False
# 3   False  False  False  False  False  False  False  False  False  False
# 4   False  False  False  False  False  False  False  False  False  False
# 5   False  False  False  False  False  False  False  False  False  False
# 6   False  False  False  False  False  False  False  False  False  False
# 7   False  False  False  False  False  False  False  False  False  False
# 8   False  False  False  False  False  False  False  False  False  False
# 9   False  False  False  False  False  False  False  False  False  False
# 10  False  False  False  False  False  False  False  False  False  False
# 11  False  False  False  False  False  False  False  False  False  False
# ...

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# So, from the above information we can say that there is no null value present in the dataset.

# %%
# TO get the statistical values for all the columns present in given dataset, we are goint to run following code,
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# # Visualization using graphs:

# %%
sns.barplot(x='R', y='W', data=df)
# Out:
# <AxesSubplot:xlabel='R', ylabel='W'>

# %%
sns.barplot(x='AB', y='W', data=df)
# Out:
# <AxesSubplot:xlabel='AB', ylabel='W'>

# %%
sns.barplot(x='H', y='W', data=df)
# Out:
# <AxesSubplot:xlabel='H', ylabel='W'>

# %%
sns.barplot(x='2B', y='W', data=df)
# Out:
# <AxesSubplot:xlabel='2B', ylabel='W'>

# %%
sns.barplot(x='3B', y='W', data=df)
# Out:
# <AxesSubplot:xlabel='3B', ylabel='W'>

# %%
sns.barplot(x='HR', y='W', data=df)
# Out:
# <AxesSubplot:xlabel='HR', ylabel='W'>

# %%
sns.barplot(x='BB', y='W', data=df)
# Out:
# <AxesSubplot:xlabel='BB', ylabel='W'>

# %%
sns.barplot(x='SO', y='W', data=df)
# Out:
# <AxesSubplot:xlabel='SO', ylabel='W'>

# %%
sns.barplot(x='SB', y='W', data=df)
# Out:
# <AxesSubplot:xlabel='SB', ylabel='W'>

# %%
sns.barplot(x='RA', y='W', data=df)
# Out:
# <AxesSubplot:xlabel='RA', ylabel='W'>

# %%
sns.barplot(x='ER', y='W', data=df)
# Out:
# <AxesSubplot:xlabel='ER', ylabel='W'>

# %%
sns.barplot(x='ERA', y='W', data=df)
# Out:
# <AxesSubplot:xlabel='ERA', ylabel='W'>

# %%
sns.barplot(x='CG', y='W', data=df)
# Out:
# <AxesSubplot:xlabel='CG', ylabel='W'>

# %%
sns.barplot(x='SHO', y='W', data=df)
# Out:
# <AxesSubplot:xlabel='SHO', ylabel='W'>

# %%
sns.barplot(x='SV', y='W', data=df)
# Out:
# <AxesSubplot:xlabel='SV', ylabel='W'>

# %%
sns.barplot(x='E', y='W', data=df)
# Out:
# <AxesSubplot:xlabel='E', ylabel='W'>

# %%
for p in df.columns:
    sns.distplot(df[p])
    plt.show()

# %% [markdown]
# From above graph plot we can say that most of the data is normally distributed includes:- W,R,AB,2B,3B,HR,BB,SB,ER,ERA,SV.
# H, E are showing bipolar distrubution.
# SO,CG,SHO is not showing normal distribution.

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
df=df[[ 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
       'ERA', 'CG', 'SHO', 'SV', 'E','W']]

# %% [markdown]
# # Heatmap:

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),annot=True,linecolor='black',linewidths=.5)
# Out:
# <AxesSubplot:>

# %%
df.hist(figsize=(10,10),color='b')
plt.show()

# %% [markdown]
# # Correlation:

# %%
df.corr()
# Out:
#             R        AB         H        2B        3B        HR        BB  \
# R    1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283  0.402452
# AB   0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983 -0.136414
# H    0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855 -0.118281
# 2B   0.560084  0.453370  0.566847  1.000000  0.220490  0.056292  0.302700
# 3B  -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915 -0.454949
# HR   0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000  0.425691
# BB   0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691  1.000000
# SO  -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923  0.233652
# SB   0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567 -0.098347
# RA  -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903 -0.416445
# ER  -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922 -0.452663
# ERA -0.049281  0.255551  0.231172 -0.254854  0.330951 -0.090917 -0.459832
# ...

# %%
#Lets check with the EDA:

# %%
sns.scatterplot('R','W',data=df)
# Out:
# <AxesSubplot:xlabel='R', ylabel='W'>

# %%
sns.scatterplot('AB','W',data=df)
# Out:
# <AxesSubplot:xlabel='AB', ylabel='W'>

# %%
sns.scatterplot('H','W',data=df)
# Out:
# <AxesSubplot:xlabel='H', ylabel='W'>

# %%
sns.scatterplot('2B','W',data=df)
# Out:
# <AxesSubplot:xlabel='2B', ylabel='W'>

# %%
sns.scatterplot('3B','W',data=df)
# Out:
# <AxesSubplot:xlabel='3B', ylabel='W'>

# %%
sns.scatterplot('HR','W',data=df)
# Out:
# <AxesSubplot:xlabel='HR', ylabel='W'>

# %%
sns.scatterplot('BB','W',data=df)
# Out:
# <AxesSubplot:xlabel='BB', ylabel='W'>

# %%
sns.scatterplot('SO','W',data=df)
# Out:
# <AxesSubplot:xlabel='SO', ylabel='W'>

# %%
sns.scatterplot('SB','W',data=df)
# Out:
# <AxesSubplot:xlabel='SB', ylabel='W'>

# %%
sns.scatterplot('RA','W',data=df)
# Out:
# <AxesSubplot:xlabel='RA', ylabel='W'>

# %%
sns.scatterplot('ER','W',data=df)
# Out:
# <AxesSubplot:xlabel='ER', ylabel='W'>

# %%
sns.scatterplot('ERA','W',data=df)
# Out:
# <AxesSubplot:xlabel='ERA', ylabel='W'>

# %%
sns.scatterplot('CG','W',data=df)
# Out:
# <AxesSubplot:xlabel='CG', ylabel='W'>

# %%
sns.scatterplot('SHO','W',data=df)
# Out:
# <AxesSubplot:xlabel='SHO', ylabel='W'>

# %%
sns.scatterplot('SV','W',data=df)
# Out:
# <AxesSubplot:xlabel='SV', ylabel='W'>

# %%
sns.scatterplot('E','W',data=df)
# Out:
# <AxesSubplot:xlabel='E', ylabel='W'>

# %% [markdown]
# R, 2B,SHO are positively correlated.
# H,3B,HR,BB,SO,CG,E are low correlated.
# SB have no correlation.
# RA,ERA is negatively correlated.

# %%
plt.figure(figsize =(25, 10))
df.corr()['W'].sort_values(ascending = False).drop(['W']).plot(kind ='bar', color ='skyblue')
plt.xlabel('Features')
plt.ylabel('Column with target names')
plt.title('Correlation')
plt.show()

# %% [markdown]
# # Checking for outliers:

# %%
df.plot(kind='box',fontsize=15,figsize=(25,25),color='black')
# Out:
# <AxesSubplot:>

# %% [markdown]
# R,ERA,SHO,SV,E having the outliers.

# %% [markdown]
# # Z-Score Method:

# %%
i=df[['R','ERA','SHO','SV','E']]
from scipy.stats import zscore
z=np.abs(zscore(i))
df_new=df[(z<3).all(axis=1)]
df_new
# Out:
#       R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0   724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1   696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2   669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3   622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4   689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
# 6   764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3    4
# 7   713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0   10
# 8   644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1   12
# 9   748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3   10
# 10  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5    9
# 11  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5   13
# ...

# %%
df_new.shape
# Out:
# (29, 17)

# %% [markdown]
# from above we can say that, outliers has been removed.

# %% [markdown]
# # Checking for skewness:

# %%
df_new.skew()
# Out:
# R     -0.215364
# AB     0.169573
# H      0.783772
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG     0.854980
# SHO    0.526943
# SV     0.627480
# E      0.840271
# W      0.119013
# dtype: float64

# %%
skew=["H","CG","SHO","SV","E"]
df_new["H"]=np.log1p(df_new["H"])

# %%
from sklearn.preprocessing import PowerTransformer
scaler = PowerTransformer(method='yeo-johnson')
'''parameters:
method = 'box_cox' or 'yeo-johnson'
'''
# Out:
# "parameters:\nmethod = 'box_cox' or 'yeo-johnson'\n"

# %%
df_new[['E','SHO','SV','CG']] = scaler.fit_transform(df_new[['E','SHO','SV','CG']].values)

# %%
df_new.skew()
# Out:
# R     -0.215364
# AB     0.169573
# H      0.738455
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG    -0.045947
# SHO    0.000529
# SV    -0.000925
# E      0.065585
# W      0.119013
# dtype: float64

# %%
#Now the skewness has been removed.

# %%
for i in df_new.columns:
    sns.distplot(df_new[i])
    plt.show()

# %% [markdown]
# # Splitting data into X and Y:

# %%
x = df_new.drop("W", axis=1)
y = df_new["W"]

# %%
x.shape
# Out:
# (29, 16)

# %%
y.shape
# Out:
# (29,)

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()
for i in range (0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=i)
    lr.fit(x_train,y_train)
    lr_predict_train=lr.predict(x_train)
    lr_predict_test=lr.predict(x_test)
    print(f'At random state {i}, The training accuracy is :-{r2_score(y_train,lr_predict_train)}')
    print(f'At random state {i}, The test accuracy is :-{r2_score(y_test,lr_predict_test)}')
    print('\n')
# Out:
# At random state 0, The training accuracy is :-0.975036606485984
# At random state 0, The test accuracy is :-0.5088733446137466
#
#
# At random state 1, The training accuracy is :-0.9663684523791738
# At random state 1, The test accuracy is :-0.7703785825241394
#
#
# At random state 2, The training accuracy is :-0.9635647792728497
# At random state 2, The test accuracy is :--0.3878981322899828
#
#
# At random state 3, The training accuracy is :-0.9562214066148795
# At random state 3, The test accuracy is :-0.867648996049989
#
#
# At random state 4, The training accuracy is :-0.9638416400784587
# At random state 4, The test accuracy is :-0.7152783009265191
#
#
# At random state 5, The training accuracy is :-0.9605952983120856
# At random state 5, The test accuracy is :-0.659996728972928
#
#
# At random state 6, The training accuracy is :-0.961448361821927
# At random state 6, The test accuracy is :-0.7110789649230373
#
#
# ...

# %%
#at Random state 67
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=67)

# %%
x_train.shape
# Out:
# (23, 16)

# %%
y_train.shape
# Out:
# (23,)

# %%
x_test.shape
# Out:
# (6, 16)

# %%
y_test.shape
# Out:
# (6,)

# %% [markdown]
# # Model building and Prediction:
# Linear Regression Model:

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(x_train,y_train)
print(lr.score(x_train,y_train))
lr_predict=lr.predict(x_test)
# Out:
# 0.9542337692049083

# %%
print('MSE:',mean_squared_error(lr_predict,y_test))
print('MAE:',mean_absolute_error(lr_predict,y_test))
print('r2_score:',r2_score(lr_predict,y_test))
print('RMSE:', np.sqrt(mean_squared_error(lr_predict,y_test)))
# Out:
# MSE: 23.69412944035785
# MAE: 3.6318374489653564
# r2_score: 0.8460951698056458
# RMSE: 4.867661598792366

# %%
plt.scatter(x=y_test,y=lr_predict)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
# Out:
# Text(0, 0.5, 'Predicted Y')

# %% [markdown]
# # Decision Tree Regressor:

# %%
from sklearn.tree import DecisionTreeRegressor

DTR = DecisionTreeRegressor()
DTR.fit(x_train,y_train)
print(DTR.score(x_train,y_train))
DTR_Predict=DTR.predict(x_test)
# Out:
# 1.0

# %%
print('MSE:',mean_squared_error(DTR_Predict,y_test))
print('MAE:',mean_absolute_error(DTR_Predict,y_test))
print('r2_score:',r2_score(DTR_Predict,y_test))
print('RMSE:', np.sqrt(mean_squared_error(DTR_Predict,y_test)))
# Out:
# MSE: 113.0
# MAE: 8.666666666666666
# r2_score: -0.0671563483735571
# RMSE: 10.63014581273465

# %%
plt.scatter(x=y_test,y=DTR_Predict)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
# Out:
# Text(0, 0.5, 'Predicted Y')

# %% [markdown]
# # Random Forest Regressor:

# %%
from sklearn.ensemble import RandomForestRegressor
rdr = RandomForestRegressor()
rdr.fit(x_train,y_train)
print(rdr.score(x_train,y_train))
rdr_Predict=rdr.predict(x_test)
# Out:
# 0.927299277247143

# %%
print('MSE:',mean_squared_error(rdr_Predict,y_test))
print('MAE:',mean_absolute_error(rdr_Predict,y_test))
print('r2_score:',r2_score(rdr_Predict,y_test))
print('RMSE:', np.sqrt(mean_squared_error(rdr_Predict,y_test)))
# Out:
# MSE: 43.93391666666668
# MAE: 6.155000000000001
# r2_score: 0.028988447903213754
# RMSE: 6.628266490317562

# %%
plt.scatter(x=y_test,y=rdr_Predict)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
# Out:
# Text(0, 0.5, 'Predicted Y')

# %% [markdown]
# # SVR:

# %%
from sklearn.svm import SVR

svr = SVR()
svr.fit(x_train,y_train)
print(svr.score(x_train,y_train))
svr_Predict=svr.predict(x_test)
# Out:
# 0.002255565994644826

# %%
print('MSE:',mean_squared_error(svr_Predict,y_test))
print('MAE:',mean_absolute_error(svr_Predict,y_test))
print('r2_score:',r2_score(svr_Predict,y_test))
print('RMSE:', np.sqrt(mean_squared_error(svr_Predict,y_test)))
# Out:
# MSE: 164.41291047627695
# MAE: 11.660468609187811
# r2_score: -614849.6082003413
# RMSE: 12.822359785791262

# %%
plt.scatter(x=y_test,y=svr_Predict)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
# Out:
# Text(0, 0.5, 'Predicted Y')

# %% [markdown]
# # Gradient Boosting Classifier:

# %%
from sklearn.ensemble import GradientBoostingRegressor

GBR = GradientBoostingRegressor()
GBR.fit(x_train,y_train)
print(GBR.score(x_train,y_train))
GBR_Predict=GBR.predict(x_test)
# Out:
# 0.9999998702313653

# %%
print('MSE:',mean_squared_error(GBR_Predict,y_test))
print('MAE:',mean_absolute_error(GBR_Predict,y_test))
print('r2_score:',r2_score(GBR_Predict,y_test))
print('RMSE:', np.sqrt(mean_squared_error(GBR_Predict,y_test)))
# Out:
# MSE: 46.32347707145899
# MAE: 6.18411025577884
# r2_score: 0.15708704764352066
# RMSE: 6.80613525221612

# %%
plt.scatter(x=y_test,y=GBR_Predict)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
# Out:
# Text(0, 0.5, 'Predicted Y')

# %% [markdown]
# # Lasso Regressor:

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso,Ridge
parameters={'alpha':[0.0001,0.001,0.01,0.1,1,10],'random_state':list(range(0,100))}
ls = Lasso()
ls.fit(x_train,y_train)
print(ls.score(x_train,y_train))
ls_Predict=ls.predict(x_test)
# Out:
# 0.8967385489770425

# %%
print('MSE:',mean_squared_error(ls_Predict,y_test))
print('MAE:',mean_absolute_error(ls_Predict,y_test))
print('r2_score:',r2_score(ls_Predict,y_test))
print('RMSE:', np.sqrt(mean_squared_error(ls_Predict,y_test)))
# Out:
# MSE: 47.50465540822947
# MAE: 5.85202368163057
# r2_score: 0.49892107349733705
# RMSE: 6.892362106580695

# %%
plt.scatter(x=y_test,y=ls_Predict)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
# Out:
# Text(0, 0.5, 'Predicted Y')

# %% [markdown]
# From all regression model, the Linear Regression model is giving 84% r2 score so we can consider it as a best fit model.

# %% [markdown]
# # Cross Validation:

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

# %%
lr = LinearRegression()

param ={
       'n_estimators':[100,200],
      'criterion':['mse','mae'],
     'min_samples_split':[2],
    'min_samples_leaf':[1],
}

# %%
lr_grid=GridSearchCV(LinearRegression(),param,cv=4,scoring='accuracy',n_jobs=-1,verbose=2)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
pred=lr.predict(x_test)
print("Accuracy: ", lr.score(x_train,y_train))
print("mean_squared_error: ",mean_squared_error(y_test,pred))
print("mean_absolute_error: ",mean_absolute_error(y_test,pred))
print("r2_score: ",r2_score(y_test,pred))
# Out:
# Accuracy:  0.9542337692049083
# mean_squared_error:  23.69412944035785
# mean_absolute_error:  3.6318374489653564
# r2_score:  0.8525261653089761

# %% [markdown]
# # Prediction:

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
lr.fit(x_train,y_train)
#lr_PRED=lr_.predict(x_test)
pred=lr.predict(x_test)
pred
# Out:
# array([98.02456246, 84.74073398, 71.28186656, 59.06357614, 84.48512934,
#        86.70743283])

# %% [markdown]
# # Saving the Model:

# %%
import joblib
joblib.dump(pred,"BaseBallCaseStudy.pkl")
# Out:
# ['BaseBallCaseStudy.pkl']

# %%
sns.distplot(pred-y_test)
# Out:
# <AxesSubplot:xlabel='W', ylabel='Density'>

# %%
plt.scatter(pred,y_test)
plt.plot(y_test,y_test,linewidth=4,color='black')

# %% [markdown]
# # END
