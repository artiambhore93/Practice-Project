# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('Bigdatamart_train')
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
df.shape
# Out:
# (8523, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
df.tail()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 8518         Snack Foods  214.5218            OUT013
# 8519        Baking Goods  108.1570            OUT045
# 8520  Health and Hygiene   85.1224            OUT035
# 8521         Snack Foods  103.1332            OUT018
# 8522         Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 8518                       1987        High               Tier 3
# 8519                       2002         NaN               Tier 2
# ...

# %%
df.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
df.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
df01=pd.read_csv('Bigdatamart_Test')
df01
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDW58       20.750          Low Fat         0.007565
# 1              FDW14        8.300              reg         0.038428
# 2              NCN55       14.600          Low Fat         0.099575
# 3              FDQ58        7.315          Low Fat         0.015388
# 4              FDY38          NaN          Regular         0.118599
# ...              ...          ...              ...              ...
# 5676           FDB58       10.500          Regular         0.013496
# 5677           FDD47        7.600          Regular         0.142991
# 5678           NCO17       10.000          Low Fat         0.073529
# 5679           FDJ26       15.300          Regular         0.000000
# 5680           FDU37        9.500          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0            Snack Foods  107.8622            OUT049
# ...

# %%
df01.shape
# Out:
# (5681, 11)

# %%
df01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5681 entries, 0 to 5680
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            5681 non-null   object
#  1   Item_Weight                4705 non-null   float64
#  2   Item_Fat_Content           5681 non-null   object
#  3   Item_Visibility            5681 non-null   float64
#  4   Item_Type                  5681 non-null   object
#  5   Item_MRP                   5681 non-null   float64
#  6   Outlet_Identifier          5681 non-null   object
#  7   Outlet_Establishment_Year  5681 non-null   int64
#  8   Outlet_Size                4075 non-null   object
#  9   Outlet_Location_Type       5681 non-null   object
#  10  Outlet_Type                5681 non-null   object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 488.3+ KB

# %%
df01.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDW58       20.750          Low Fat         0.007565  Snack Foods
# 1           FDW14        8.300              reg         0.038428        Dairy
# 2           NCN55       14.600          Low Fat         0.099575       Others
# 3           FDQ58        7.315          Low Fat         0.015388  Snack Foods
# 4           FDY38          NaN          Regular         0.118599        Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  107.8622            OUT049                       1999      Medium
# 1   87.3198            OUT017                       2007         NaN
# 2  241.7538            OUT010                       1998         NaN
# 3  155.0340            OUT017                       2007         NaN
# 4  234.2300            OUT027                       1985      Medium
#
#   Outlet_Location_Type        Outlet_Type
# ...

# %%
df01.tail()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 5676           FDB58         10.5          Regular         0.013496
# 5677           FDD47          7.6          Regular         0.142991
# 5678           NCO17         10.0          Low Fat         0.073529
# 5679           FDJ26         15.3          Regular         0.000000
# 5680           FDU37          9.5          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 5676         Snack Foods  141.3154            OUT046
# 5677       Starchy Foods  169.1448            OUT018
# 5678  Health and Hygiene  118.7440            OUT045
# 5679              Canned  214.6218            OUT017
# 5680              Canned   79.7960            OUT045
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 5676                       1997       Small               Tier 1
# 5677                       2009      Medium               Tier 3
# ...

# %%
df01.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# dtype: object

# %%
df01.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type'],
#       dtype='object')

# %%
Test=df
Train=df01

# %%
Test
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
Train
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDW58       20.750          Low Fat         0.007565
# 1              FDW14        8.300              reg         0.038428
# 2              NCN55       14.600          Low Fat         0.099575
# 3              FDQ58        7.315          Low Fat         0.015388
# 4              FDY38          NaN          Regular         0.118599
# ...              ...          ...              ...              ...
# 5676           FDB58       10.500          Regular         0.013496
# 5677           FDD47        7.600          Regular         0.142991
# 5678           NCO17       10.000          Low Fat         0.073529
# 5679           FDJ26       15.300          Regular         0.000000
# 5680           FDU37        9.500          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0            Snack Foods  107.8622            OUT049
# ...

# %% [markdown]
# # Checking for the null values

# %%
Test.isnull()
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0               False        False             False            False
# 1               False        False             False            False
# 2               False        False             False            False
# 3               False        False             False            False
# 4               False        False             False            False
# ...               ...          ...               ...              ...
# 8518            False        False             False            False
# 8519            False        False             False            False
# 8520            False        False             False            False
# 8521            False        False             False            False
# 8522            False        False             False            False
#
#       Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %%
Test.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
Train.isnull()
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0               False        False             False            False
# 1               False        False             False            False
# 2               False        False             False            False
# 3               False        False             False            False
# 4               False         True             False            False
# ...               ...          ...               ...              ...
# 5676            False        False             False            False
# 5677            False        False             False            False
# 5678            False        False             False            False
# 5679            False        False             False            False
# 5680            False        False             False            False
#
#       Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %%
Train.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                   976
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %% [markdown]
# There are null values in both the datasets of columns name Item_Weight and Outlet_Size, so removing the null values from the Train dataset

# %%
Train['Outlet_Size'].fillna(Train['Outlet_Size'].mode()[0], inplace=True)
Train['Outlet_Size'].value_counts()
# Out:
# Medium    3468
# Small     1592
# High       621
# Name: Outlet_Size, dtype: int64

# %%
Train['Item_Weight'].fillna(Train['Item_Weight'].mode()[0], inplace=True)
Train['Item_Weight'].value_counts()
# Out:
# 10.500    1033
# 17.600      53
# 15.600      48
# 20.250      47
# 19.350      46
#           ...
# 6.980        1
# 6.320        1
# 5.465        1
# 5.945        1
# 7.670        1
# Name: Item_Weight, Length: 410, dtype: int64

# %%
Train.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# dtype: int64

# %%
for i in Train.columns:
    print(Train[i].value_counts())
    print('\n')
# Out:
# DRF48    8
# FDZ50    8
# FDQ60    8
# FDN52    8
# FDW10    8
#         ..
# FDW49    1
# FDG38    1
# FDD38    1
# FDA15    1
# FDF04    1
# Name: Item_Identifier, Length: 1543, dtype: int64
#
#
# 10.500    1033
# 17.600      53
# 15.600      48
# 20.250      47
# 19.350      46
#           ...
# 6.980        1
# 6.320        1
# 5.465        1
# 5.945        1
# 7.670        1
# Name: Item_Weight, Length: 410, dtype: int64
#
#
# Low Fat    3396
# Regular    1935
# LF          206
# reg          78
# low fat      66
# Name: Item_Fat_Content, dtype: int64
#
#
# 0.000000    353
# 0.060879      2
# 0.097213      2
# 0.058461      2
# 0.058132      2
#            ...
# 0.082382      1
# 0.026175      1
# 0.155144      1
# 0.069557      1
# 0.104720      1
# Name: Item_Visibility, Length: 5277, dtype: int64
#
#
# Snack Foods              789
# Fruits and Vegetables    781
# Household                638
# Frozen Foods             570
# Dairy                    454
# ...

# %%
Test.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
Train.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year
# count  5681.000000      5681.000000  5681.000000                5681.000000
# mean     12.318422         0.065684   141.023273                1997.828903
# std       4.325238         0.051252    61.809091                   8.372256
# min       4.555000         0.000000    31.990000                1985.000000
# 25%       9.195000         0.027047    94.412000                1987.000000
# 50%      10.500000         0.054154   141.415400                1999.000000
# 75%      15.850000         0.093463   186.026600                2004.000000
# max      21.350000         0.323637   266.588400                2009.000000

# %%
# Analysing the train data:
#Data Visualization

# %%
Train.hist(figsize=(10,10),color='c')
plt.show()

# %%
sns.distplot(Train['Item_Weight'])
# Out:
# <AxesSubplot:xlabel='Item_Weight', ylabel='Density'>

# %%
sns.distplot(Train['Item_Visibility'])
# Out:
# <AxesSubplot:xlabel='Item_Visibility', ylabel='Density'>

# %%
sns.distplot(Train['Item_MRP'])
# Out:
# <AxesSubplot:xlabel='Item_MRP', ylabel='Density'>

# %%
sns.distplot(Train['Outlet_Establishment_Year'])
# Out:
# <AxesSubplot:xlabel='Outlet_Establishment_Year', ylabel='Density'>

# %%
sns.pairplot(Train)

# %%
sns.countplot(y='Item_Type',data=Train)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Item_Type'>

# %% [markdown]
# From the above Snack Foods and Fruits and Vegetables are sold the maximum as compare to other Items, Seafood selling count is very low.

# %%
sns.countplot(y='Outlet_Size',data=Train)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Outlet_Size'>

# %% [markdown]
# The Medium size outlets having maximum count.

# %%
sns.countplot(y='Outlet_Type',data=Train)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Outlet_Type'>

# %% [markdown]
# Supermarket type1 outlets having maximum count.

# %%
sns.countplot(x='Outlet_Identifier',data=Train)
# Out:
# <AxesSubplot:xlabel='Outlet_Identifier', ylabel='count'>

# %%
sns.countplot(x='Outlet_Location_Type',data=Train)
# Out:
# <AxesSubplot:xlabel='Outlet_Location_Type', ylabel='count'>

# %% [markdown]
# correlation

# %%
corr=df.corr()
plt.figure(figsize=(10,10))
sns.heatmap(Train.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
Train.skew()
# Out:
# Item_Weight                  0.374935
# Item_Visibility              1.238312
# Item_MRP                     0.136182
# Outlet_Establishment_Year   -0.396306
# dtype: float64

# %%
columns=['Item_Weight','Item_Visibility','Item_MRP','Outlet_Establishment_Year']

# %%
for i in columns:
    sns.boxplot(df[i])
    plt.show()

# %% [markdown]
# From above we can say that, Item_Visibility column have outliers

# %%
from scipy.stats import zscore

# %%
Variable=df['Item_Visibility']
z=np.abs(zscore(Variable))
new_train = Train[(z<3)]
new_train
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDW58       20.750          Low Fat         0.007565
# 1              FDW14        8.300              reg         0.038428
# 2              NCN55       14.600          Low Fat         0.099575
# 3              FDQ58        7.315          Low Fat         0.015388
# 4              FDY38       10.500          Regular         0.118599
# ...              ...          ...              ...              ...
# 5676           FDB58       10.500          Regular         0.013496
# 5677           FDD47        7.600          Regular         0.142991
# 5678           NCO17       10.000          Low Fat         0.073529
# 5679           FDJ26       15.300          Regular         0.000000
# 5680           FDU37        9.500          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0            Snack Foods  107.8622            OUT049
# ...

# %%
new_train.shape
# Out:
# (5621, 11)

# %%
new_train.skew
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.skew of      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDW58       20.750          Low Fat         0.007565
# 1              FDW14        8.300              reg         0.038428
# 2              NCN55       14.600          Low Fat         0.099575
# 3              FDQ58        7.315          Low Fat         0.015388
# 4              FDY38       10.500          Regular         0.118599
# ...              ...          ...              ...              ...
# 5676           FDB58       10.500          Regular         0.013496
# 5677           FDD47        7.600          Regular         0.142991
# 5678           NCO17       10.000          Low Fat         0.073529
# 5679           FDJ26       15.300          Regular         0.000000
# 5680           FDU37        9.500          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
Object=['Item_Identifier','Item_Fat_Content','Item_Type','Outlet_Identifier','Outlet_Size','Outlet_Location_Type','Outlet_Type']

# %%
for i in Object:
    df[i]=le.fit_transform(df[i])
df
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0                 156        9.300                 1         0.016047
# 1                   8        5.920                 2         0.019278
# 2                 662       17.500                 1         0.016760
# 3                1121       19.200                 2         0.000000
# 4                1297        8.930                 1         0.000000
# ...               ...          ...               ...              ...
# 8518              370        6.865                 1         0.056783
# 8519              897        8.380                 2         0.046982
# 8520             1357       10.600                 1         0.035186
# 8521              681        7.210                 2         0.145221
# 8522               50       14.800                 1         0.044878
#
#       Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %%
df_x=df.drop(columns='Item_Outlet_Sales')
y=df['Item_Outlet_Sales']
df_x
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0                 156        9.300                 1         0.016047
# 1                   8        5.920                 2         0.019278
# 2                 662       17.500                 1         0.016760
# 3                1121       19.200                 2         0.000000
# 4                1297        8.930                 1         0.000000
# ...               ...          ...               ...              ...
# 8518              370        6.865                 1         0.056783
# 8519              897        8.380                 2         0.046982
# 8520             1357       10.600                 1         0.035186
# 8521              681        7.210                 2         0.145221
# 8522               50       14.800                 1         0.044878
#
#       Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %%
from sklearn.preprocessing import PowerTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
sc_x=sc.fit_transform(df_x)

# %%
sc_x
# Out:
# array([[-1.38851383, -0.7662174 , -0.57284357, ..., -0.74445778,
#         -1.36933384, -0.25265831],
#        [-1.71799137, -1.49417499,  0.97809218, ..., -0.74445778,
#          1.09156913,  1.00297245],
#        [-0.26205684,  0.99983356, -0.57284357, ..., -0.74445778,
#         -1.36933384, -0.25265831],
#        ...,
#        [ 1.28515188, -0.48623371, -0.57284357, ...,  0.26653866,
#         -0.13888236, -0.25265831],
#        [-0.21975905, -1.21634502,  0.97809218, ..., -0.74445778,
#          1.09156913,  1.00297245],
#        [-1.62449099,  0.41832897, -0.57284357, ...,  0.26653866,
#         -1.36933384, -0.25265831]])

# %%
x=sc_x
x=pd.DataFrame(x,columns=df_x.columns)

# %%
x
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0           -1.388514    -0.766217         -0.572844        -0.970732
# 1           -1.717991    -1.494175          0.978092        -0.908111
# 2           -0.262057     0.999834         -0.572844        -0.956917
# 3            0.759769     1.365966          0.978092        -1.281758
# 4            1.151580    -0.845905         -0.572844        -1.281758
# ...               ...          ...               ...              ...
# 8518        -0.912107    -1.290648         -0.572844        -0.181193
# 8519         0.261100    -0.964360          0.978092        -0.371154
# 8520         1.285152    -0.486234         -0.572844        -0.599784
# 8521        -0.219759    -1.216345          0.978092         1.532880
# 8522        -1.624491     0.418329         -0.572844        -0.411936
#
#       Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %%
x.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                     0
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %%
x['Item_Weight'].fillna(x['Item_Weight'].mode()[0], inplace=True)
x['Item_Weight'].value_counts()
# Out:
# -0.152407    1549
#  1.021371      82
#  0.170651      77
# -0.227787      76
# -0.766217      68
#              ...
# -1.202346       2
# -1.114043       1
# -0.740373       1
# -1.364952       1
# -1.606168       1
# Name: Item_Weight, Length: 415, dtype: int64

# %%
x.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# dtype: int64

# %% [markdown]
# Models

# %%
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=i)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    print(f'At random state {i},the training accuracy is: {r2_score(y_train,pred_train)}')
    print(f'At random state {i},the testing accuracy is: {r2_score(y_test,pred_test)}')
    print('\n')
# Out:
# At random state 0,the training accuracy is: 0.5011892662901969
# At random state 0,the testing accuracy is: 0.5047337042129019
#
#
# At random state 1,the training accuracy is: 0.5027513207936793
# At random state 1,the testing accuracy is: 0.49800673184290434
#
#
# At random state 2,the training accuracy is: 0.5056311818377139
# At random state 2,the testing accuracy is: 0.48682547562304734
#
#
# At random state 3,the training accuracy is: 0.4932524075303232
# At random state 3,the testing accuracy is: 0.5353921536444797
#
#
# At random state 4,the training accuracy is: 0.5041174984963956
# At random state 4,the testing accuracy is: 0.49099678239042177
#
#
# At random state 5,the training accuracy is: 0.5039013557616012
# At random state 5,the testing accuracy is: 0.4937131617791234
#
#
# At random state 6,the training accuracy is: 0.5020075646928999
# At random state 6,the testing accuracy is: 0.5004441233966904
#
#
# At random state 7,the training accuracy is: 0.5055806223221603
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=50)

# %%
from sklearn.svm import SVR
kernellist=['linear','poly','rbf']
for i in kernellist:
    sv=SVR(kernel=i)
    sv.fit(x_train,y_train)
    print(sv.score(x_train,y_train))
# Out:
# 0.4659979545368651
# 0.08192912808986108
# 0.05082122098404451

# %%
sv=SVR(kernel='linear')
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor

dt=DecisionTreeRegressor()
rf=RandomForestRegressor()
ab=AdaBoostRegressor()

model=[lr,sv,dt,rf,ab]

for m in model:
    m.fit(x_train,y_train)
    pred_train=m.predict(x_train)
    pred_test=m.predict(x_test)
    train_score=r2_score(y_train,pred_train)
    test_score=r2_score(y_test,pred_test)
    print('Accuracy of', m )
    print('Training Score', train_score)
    print('Testing Score', test_score)
    print('\n')
# Out:
# Accuracy of LinearRegression()
# Training Score 0.501409409669
# Testing Score 0.5038115633479385
#
#
# Accuracy of SVR(kernel='linear')
# Training Score 0.4659979545368651
# Testing Score 0.4688311201894264
#
#
# Accuracy of DecisionTreeRegressor()
# Training Score 1.0
# Testing Score 0.23078987829680742
#
#
# Accuracy of RandomForestRegressor()
# Training Score 0.9364118313495163
# Testing Score 0.575276767816743
#
#
# Accuracy of AdaBoostRegressor()
# Training Score 0.5517809594478706
# Testing Score 0.5418717878243151

# %%
from sklearn.model_selection import cross_val_score

# %%
model=(lr,sv,dt,rf,ab)
for m in model:
    score=cross_val_score(m,x,y,cv=5)
    print('Mean Accuracy of', m)
    print(score.mean())
    print('\n')
# Out:
# Mean Accuracy of LinearRegression()
# 0.4997874118233973
#
#
# Mean Accuracy of SVR(kernel='linear')
# 0.4626986752384643
#
#
# Mean Accuracy of DecisionTreeRegressor()
# 0.13482494165195918
#
#
# Mean Accuracy of RandomForestRegressor()
# 0.5497327686747134
#
#
# Mean Accuracy of AdaBoostRegressor()
# 0.4458163656990381

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso

# %%
parameters={'alpha':[.0001,.001,.01,.1,1,10],'random_state':list(range(0,10))}
ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 10, 'random_state': 0}

# %%
ls=Lasso(alpha=10,random_state=0)
ls.fit(x_train,y_train)
pred_ls=ls.predict(x_test)
lss=r2_score(y_test,pred_ls)
lss
# Out:
# 0.5033811961145811

# %%
cv_score=cross_val_score(ls,x,y,cv=5)
cv_mean=cv_score.mean()
cv_mean
# Out:
# 0.5000326927616848

# %%
Finalmod=LinearRegression(copy_X=True, fit_intercept= True, n_jobs=None, normalize=False)
Finalmod.fit(x_train,y_train)
pred_final=Finalmod.predict(x_test)
rfs=r2_score(y_test,pred_final)
print('R2 Score', rfs*100)

rfscore=cross_val_score(Finalmod,x,y,cv=5)
rfc=rfscore.mean()
print('Cross Val score', rfc*100)
# Out:
# R2 Score 50.38115633479385
# Cross Val score 49.97874118233973

# %% [markdown]
# We got 50% accuracy

# %% [markdown]
# The End
