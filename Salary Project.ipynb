# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Salaries")
df
# Out:
#          rank discipline  yrs.since.phd  yrs.service   sex  salary
# 0        Prof          B             19           18  Male  139750
# 1        Prof          B             20           16  Male  173200
# 2    AsstProf          B              4            3  Male   79750
# 3        Prof          B             45           39  Male  115000
# 4        Prof          B             40           41  Male  141500
# ..        ...        ...            ...          ...   ...     ...
# 392      Prof          A             33           30  Male  103106
# 393      Prof          A             31           19  Male  150564
# 394      Prof          A             42           25  Male  101738
# 395      Prof          A             25           15  Male   95329
# 396  AsstProf          A              8            4  Male   81035
#
# [397 rows x 6 columns]

# %%
df.head()
# Out:
#        rank discipline  yrs.since.phd  yrs.service   sex  salary
# 0      Prof          B             19           18  Male  139750
# 1      Prof          B             20           16  Male  173200
# 2  AsstProf          B              4            3  Male   79750
# 3      Prof          B             45           39  Male  115000
# 4      Prof          B             40           41  Male  141500

# %%
df.tail()
# Out:
#          rank discipline  yrs.since.phd  yrs.service   sex  salary
# 392      Prof          A             33           30  Male  103106
# 393      Prof          A             31           19  Male  150564
# 394      Prof          A             42           25  Male  101738
# 395      Prof          A             25           15  Male   95329
# 396  AsstProf          A              8            4  Male   81035

# %%
df.isnull()
# Out:
#       rank  discipline  yrs.since.phd  yrs.service    sex  salary
# 0    False       False          False        False  False   False
# 1    False       False          False        False  False   False
# 2    False       False          False        False  False   False
# 3    False       False          False        False  False   False
# 4    False       False          False        False  False   False
# ..     ...         ...            ...          ...    ...     ...
# 392  False       False          False        False  False   False
# 393  False       False          False        False  False   False
# 394  False       False          False        False  False   False
# 395  False       False          False        False  False   False
# 396  False       False          False        False  False   False
#
# [397 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# rank             0
# discipline       0
# yrs.since.phd    0
# yrs.service      0
# sex              0
# salary           0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (397, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   rank           397 non-null    object
#  1   discipline     397 non-null    object
#  2   yrs.since.phd  397 non-null    int64
#  3   yrs.service    397 non-null    int64
#  4   sex            397 non-null    object
#  5   salary         397 non-null    int64
# dtypes: int64(3), object(3)
# memory usage: 18.7+ KB

# %%
df.drop_duplicates()
# Out:
#          rank discipline  yrs.since.phd  yrs.service   sex  salary
# 0        Prof          B             19           18  Male  139750
# 1        Prof          B             20           16  Male  173200
# 2    AsstProf          B              4            3  Male   79750
# 3        Prof          B             45           39  Male  115000
# 4        Prof          B             40           41  Male  141500
# ..        ...        ...            ...          ...   ...     ...
# 392      Prof          A             33           30  Male  103106
# 393      Prof          A             31           19  Male  150564
# 394      Prof          A             42           25  Male  101738
# 395      Prof          A             25           15  Male   95329
# 396  AsstProf          A              8            4  Male   81035
#
# [393 rows x 6 columns]

# %%
df.describe()
# Out:
#        yrs.since.phd  yrs.service         salary
# count     397.000000   397.000000     397.000000
# mean       22.314861    17.614610  113706.458438
# std        12.887003    13.006024   30289.038695
# min         1.000000     0.000000   57800.000000
# 25%        12.000000     7.000000   91000.000000
# 50%        21.000000    16.000000  107300.000000
# 75%        32.000000    27.000000  134185.000000
# max        56.000000    60.000000  231545.000000

# %%
sns.scatterplot(x="rank",y="salary",data=df)
sns.scatterplot(x="discipline",y="salary",data=df)
sns.scatterplot(x="yrs.since.hd",y="salary",data=df)
sns.scatterplot(x="yrs.service",y="salary",data=df)
sns.scatterplot(x="sex",y="salary",data=df)
# Out:
# <AxesSubplot:xlabel='rank', ylabel='salary'>

# %%
sns.scatterplot(x="rank",y="salary",data=df)
# Out:
# <AxesSubplot:xlabel='rank', ylabel='salary'>

# %%
sns.scatterplot(x="yrs.since.phd",y="salary",data=df)
# Out:
# <AxesSubplot:xlabel='yrs.since.phd', ylabel='salary'>

# %%
sns.scatterplot(x="yrs.since.phd",y="salary",data=df)
# Out:
# <AxesSubplot:xlabel='yrs.since.phd', ylabel='salary'>

# %%
sns.scatterplot(x="yrs.service",y="salary",data=df)
# Out:
# <AxesSubplot:xlabel='yrs.service', ylabel='salary'>

# %%
sns.scatterplot(x="sex",y="salary",data=df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='salary'>

# %%
sns.pairplot(df)

# %%
df.corr()
# Out:
#                yrs.since.phd  yrs.service    salary
# yrs.since.phd       1.000000     0.909649  0.419231
# yrs.service         0.909649     1.000000  0.334745
# salary              0.419231     0.334745  1.000000

# %%
df.corr()['salary'].sort_values()
# Out:
# yrs.service      0.334745
# yrs.since.phd    0.419231
# salary           1.000000
# Name: salary, dtype: float64

# %%
plt.figure(figsize=(5,3))
sns.heatmap(df.corr(),annot=True,linewidth=0.5,linecolor='black',fmt= '.3f')
# Out:
# <AxesSubplot:>

# %%
df.describe()
# Out:
#        yrs.since.phd  yrs.service         salary
# count     397.000000   397.000000     397.000000
# mean       22.314861    17.614610  113706.458438
# std        12.887003    13.006024   30289.038695
# min         1.000000     0.000000   57800.000000
# 25%        12.000000     7.000000   91000.000000
# 50%        21.000000    16.000000  107300.000000
# 75%        32.000000    27.000000  134185.000000
# max        56.000000    60.000000  231545.000000

# %%
round(df.describe()[1:].transpose(),3)
# Out:
#                      mean        std      min      25%       50%       75%  \
# yrs.since.phd      22.315     12.887      1.0     12.0      21.0      32.0
# yrs.service        17.615     13.006      0.0      7.0      16.0      27.0
# salary         113706.458  30289.039  57800.0  91000.0  107300.0  134185.0
#
#                     max
# yrs.since.phd      56.0
# yrs.service        60.0
# salary         231545.0

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,3))
sns.heatmap(round(df.describe()[1:].transpose(),3), annot=True, linewidths=0.25, linecolor="black", fmt= 'f')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title("Summary")
plt.savefig("heatmap.png")
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   rank           397 non-null    object
#  1   discipline     397 non-null    object
#  2   yrs.since.phd  397 non-null    int64
#  3   yrs.service    397 non-null    int64
#  4   sex            397 non-null    object
#  5   salary         397 non-null    int64
# dtypes: int64(3), object(3)
# memory usage: 18.7+ KB

# %%
collist=df.columns.values
collist
# Out:
# array(['rank', 'discipline', 'yrs.since.phd', 'yrs.service', 'sex',
#        'salary'], dtype=object)

# %%
len(list(range(0,len(collist))))
# Out:
# 6

# %%
range(0,len(collist))
# Out:
# range(0, 6)

# %%
for i in range(0,len(collist)):
    print(collist[i])
    break
# Out:
# rank

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df.skew()
# Out:
# yrs.since.phd    0.300880
# yrs.service      0.650569
# salary           0.714568
# dtype: float64

# %%
sns.distplot(df['yrs.since.phd'])
# Out:
# <AxesSubplot:xlabel='yrs.since.phd', ylabel='Density'>

# %%
sns.distplot(df["yrs.service"])
# Out:
# <AxesSubplot:xlabel='yrs.service', ylabel='Density'>

# %%
sns.distplot(df['salary'])
# Out:
# <AxesSubplot:xlabel='salary', ylabel='Density'>

# %%
ax = df.plot(y="yrs.since.phd", x="salary", kind="bar",color='C3')
df.plot(y="yrs.service", x="salary", kind="bar", ax=ax, color="C1")

plt.show()

# %%
print('max:',df['salary'].max())
print('min:',df['salary'].min())
add=df['salary'].max()-df['salary'].min()
grp=round(add/3,3)
print('range difference:',(grp))
# Out:
# max: 231545
# min: 57800
# range difference: 57915.0

# %%
low=df['salary'].min()+grp
mid=low+grp

print('upper bound of Low grp',low)
print('upper bound of Mid grp',mid)
print('upper bound of High grp','max:',df['salary'].max())
# Out:
# upper bound of Low grp 115715.0
# upper bound of Mid grp 173630.0
# upper bound of High grp max: 231545
